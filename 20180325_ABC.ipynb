# %% [markdown]
# https://beta.atcoder.jp/contests/abc092/tasks

# %% [markdown]
# # C

# %%
n = int(input())
a_list = list(map(int,input().split()))
a_list = [0] + a_list + [0]
s = 0
for i in range(len(a_list)-1):
    s += abs(a_list[i+1]-a_list[i])
    
for i in range(0,len(a_list)-2):
    p = s - abs(a_list[i+1] - a_list[i]) - abs(a_list[i+2] - a_list[i+1]) + abs(a_list[i+2] - a_list[i])
    print(p)
# Out:
# 5
# 1 1 1 2 0
# 4
# 4
# 4
# 2
# 4

# %% [markdown]
# # D

# %%
A, B = map(int, input().split())
print(100, 100)
ans = [["."]*50 + ["#"]*50 for i in range(100)]


for a in range(A - 1):
    ans[2*(a // 25)][99 - 2*(a % 25)] = "."
for b in range(B - 1):
    ans[2*(b // 25)][2*(b % 25)] = "#"
for l in ans:
    print("".join(l))
# Out:
# 3 5
# 100 100
# #.#.#.#...........................................###############################################.#.
# ..................................................##################################################
# ..................................................##################################################
# ..................................................##################################################
# ..................................................##################################################
# ..................................................##################################################
# ..................................................##################################################
# ..................................................##################################################
# ..................................................##################################################
# ...

# %%
len(ans)
# Out:
# 100

# %%
ans[0]
# Out:
# ['.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#']

# %%
for a in range(A - 1):
    ans[2*(a // 25)][99 - 2*(a % 25)] = "."
for b in range(B - 1):
    ans[2*(b // 25)][2*(b % 25)] = "#"
for l in ans:
    print("".join(l))
